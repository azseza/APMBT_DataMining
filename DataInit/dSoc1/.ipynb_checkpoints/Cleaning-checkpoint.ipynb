# %%
import pandas as pd
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-36-41e0c2ad92c5> in <module>
#       1 import pandas as pd
# ----> 2 import matplotlib
#
# ModuleNotFoundError: No module named 'matplotlib'

# %%
pd.read_csv('marketIntrest.csv')
# Out:
#       44176 Unnamed: 1                      Unnamed: 2  \
# 0   Regions   Calendar  Monetary market interest rates
# 1   Tunisia   Jan 2018                             5.5
# 2   Tunisia   Feb 2018                             5.6
# 3   Tunisia   Mar 2018                             6.0
# 4   Tunisia   Apr 2018                             6.5
# 5   Tunisia   May 2018                             6.4
# 6   Tunisia   Jun 2018                             6.7
# 7   Tunisia   Jul 2018                             7.3
# 8   Tunisia   Aug 2018                             7.3
# 9   Tunisia   Sep 2018                             7.3
# 10  Tunisia   Oct 2018                             7.3
# 11  Tunisia   Nov 2018                             7.3
# 12  Tunisia   Dec 2018                             7.2
# 13  Tunisia   Jan 2019                             7.2
# 14  Tunisia   Feb 2019                             7.3
# 15  Tunisia   Mar 2019                             7.9
# ...

# %%
df=pd.read_csv('marketIntrest.csv')

# %%
df[1:]
# Out:
#       44176 Unnamed: 1 Unnamed: 2 Unnamed: 3
# 1   Tunisia   Jan 2018        5.5        5.0
# 2   Tunisia   Feb 2018        5.6        5.0
# 3   Tunisia   Mar 2018        6.0        5.0
# 4   Tunisia   Apr 2018        6.5        5.0
# 5   Tunisia   May 2018        6.4        5.0
# 6   Tunisia   Jun 2018        6.7        5.0
# 7   Tunisia   Jul 2018        7.3        5.0
# 8   Tunisia   Aug 2018        7.3        5.0
# 9   Tunisia   Sep 2018        7.3        5.0
# 10  Tunisia   Oct 2018        7.3        5.0
# 11  Tunisia   Nov 2018        7.3        5.0
# 12  Tunisia   Dec 2018        7.2        5.0
# 13  Tunisia   Jan 2019        7.2        5.0
# 14  Tunisia   Feb 2019        7.3        5.0
# 15  Tunisia   Mar 2019        7.9        5.0
# 16  Tunisia   Apr 2019        7.9        5.0
# 17  Tunisia   May 2019        7.8        5.0
# 18  Tunisia   Jun 2019        7.8        5.0
# 19  Tunisia   Jul 2019        7.8        5.0
# 20  Tunisia   Aug 2019        7.8        5.0
# ...

# %%
df =df[1:]

# %%
df.shape
# Out:
# (23, 4)

# %%
df.index
# Out:
# RangeIndex(start=1, stop=24, step=1)

# %%
df.info
# Out:
# <bound method DataFrame.info of       44176 Unnamed: 1 Unnamed: 2 Unnamed: 3
# 1   Tunisia   Jan 2018        5.5        5.0
# 2   Tunisia   Feb 2018        5.6        5.0
# 3   Tunisia   Mar 2018        6.0        5.0
# 4   Tunisia   Apr 2018        6.5        5.0
# 5   Tunisia   May 2018        6.4        5.0
# 6   Tunisia   Jun 2018        6.7        5.0
# 7   Tunisia   Jul 2018        7.3        5.0
# 8   Tunisia   Aug 2018        7.3        5.0
# 9   Tunisia   Sep 2018        7.3        5.0
# 10  Tunisia   Oct 2018        7.3        5.0
# 11  Tunisia   Nov 2018        7.3        5.0
# 12  Tunisia   Dec 2018        7.2        5.0
# 13  Tunisia   Jan 2019        7.2        5.0
# 14  Tunisia   Feb 2019        7.3        5.0
# 15  Tunisia   Mar 2019        7.9        5.0
# 16  Tunisia   Apr 2019        7.9        5.0
# 17  Tunisia   May 2019        7.8        5.0
# 18  Tunisia   Jun 2019        7.8        5.0
# 19  Tunisia   Jul 2019        7.8        5.0
# ...

# %%
df.drop(3,axis=0)
# Out:
#       44176 Unnamed: 1 Unnamed: 2 Unnamed: 3
# 1   Tunisia   Jan 2018        5.5        5.0
# 2   Tunisia   Feb 2018        5.6        5.0
# 4   Tunisia   Apr 2018        6.5        5.0
# 5   Tunisia   May 2018        6.4        5.0
# 6   Tunisia   Jun 2018        6.7        5.0
# 7   Tunisia   Jul 2018        7.3        5.0
# 8   Tunisia   Aug 2018        7.3        5.0
# 9   Tunisia   Sep 2018        7.3        5.0
# 10  Tunisia   Oct 2018        7.3        5.0
# 11  Tunisia   Nov 2018        7.3        5.0
# 12  Tunisia   Dec 2018        7.2        5.0
# 13  Tunisia   Jan 2019        7.2        5.0
# 14  Tunisia   Feb 2019        7.3        5.0
# 15  Tunisia   Mar 2019        7.9        5.0
# 16  Tunisia   Apr 2019        7.9        5.0
# 17  Tunisia   May 2019        7.8        5.0
# 18  Tunisia   Jun 2019        7.8        5.0
# 19  Tunisia   Jul 2019        7.8        5.0
# 20  Tunisia   Aug 2019        7.8        5.0
# 21  Tunisia   Sep 2019        7.8        5.0
# ...

# %%
adf = pd.read_csv('IPI.csv')

# %%
pd.merge(df,adf,how='left')
# Out:
#       44176 Unnamed: 1 Unnamed: 2 Unnamed: 3 Tunisia, 11.12.2020 Unnamed: 4
# 0   Tunisia   Jan 2018        5.5        5.0                 NaN        NaN
# 1   Tunisia   Feb 2018        5.6        5.0                 NaN        NaN
# 2   Tunisia   Mar 2018        6.0        5.0                 NaN        NaN
# 3   Tunisia   Apr 2018        6.5        5.0                 NaN        NaN
# 4   Tunisia   May 2018        6.4        5.0                 NaN        NaN
# 5   Tunisia   Jun 2018        6.7        5.0                 NaN        NaN
# 6   Tunisia   Jul 2018        7.3        5.0                 NaN        NaN
# 7   Tunisia   Aug 2018        7.3        5.0                 NaN        NaN
# 8   Tunisia   Sep 2018        7.3        5.0                 NaN        NaN
# 9   Tunisia   Oct 2018        7.3        5.0                 NaN        NaN
# 10  Tunisia   Nov 2018        7.3        5.0                 NaN        NaN
# ...

# %%
adf
# Out:
#    Tunisia, 11.12.2020                                      Unnamed: 1  \
# 0             Calendar  Industrial production index (ipi) (2010 = 100)
# 1             Jan 2018                                            92.8
# 2             Feb 2018                                            88.3
# 3             Mar 2018                                            92.6
# 4             Apr 2018                                            89.5
# 5             May 2018                                            94.8
# 6             Jun 2018                                            94.2
# 7             Jul 2018                                            97.9
# 8             Aug 2018                                            89.0
# 9             Sep 2018                                            92.9
# 10            Oct 2018                                            94.1
# 11            Nov 2018                                            88.5
# ...

# %%
df.reset_index()
# Out:
#     index    44176 Unnamed: 1 Unnamed: 2 Unnamed: 3
# 0       1  Tunisia   Jan 2018        5.5        5.0
# 1       2  Tunisia   Feb 2018        5.6        5.0
# 2       3  Tunisia   Mar 2018        6.0        5.0
# 3       4  Tunisia   Apr 2018        6.5        5.0
# 4       5  Tunisia   May 2018        6.4        5.0
# 5       6  Tunisia   Jun 2018        6.7        5.0
# 6       7  Tunisia   Jul 2018        7.3        5.0
# 7       8  Tunisia   Aug 2018        7.3        5.0
# 8       9  Tunisia   Sep 2018        7.3        5.0
# 9      10  Tunisia   Oct 2018        7.3        5.0
# 10     11  Tunisia   Nov 2018        7.3        5.0
# 11     12  Tunisia   Dec 2018        7.2        5.0
# 12     13  Tunisia   Jan 2019        7.2        5.0
# 13     14  Tunisia   Feb 2019        7.3        5.0
# 14     15  Tunisia   Mar 2019        7.9        5.0
# 15     16  Tunisia   Apr 2019        7.9        5.0
# 16     17  Tunisia   May 2019        7.8        5.0
# ...

# %%
df[]
# Out:
#       44176 Unnamed: 1 Unnamed: 2 Unnamed: 3
# 3   Tunisia   Mar 2018        6.0        5.0
# 4   Tunisia   Apr 2018        6.5        5.0
# 5   Tunisia   May 2018        6.4        5.0
# 6   Tunisia   Jun 2018        6.7        5.0
# 7   Tunisia   Jul 2018        7.3        5.0
# 8   Tunisia   Aug 2018        7.3        5.0
# 9   Tunisia   Sep 2018        7.3        5.0
# 10  Tunisia   Oct 2018        7.3        5.0
# 11  Tunisia   Nov 2018        7.3        5.0
# 12  Tunisia   Dec 2018        7.2        5.0
# 13  Tunisia   Jan 2019        7.2        5.0
# 14  Tunisia   Feb 2019        7.3        5.0
# 15  Tunisia   Mar 2019        7.9        5.0
# 16  Tunisia   Apr 2019        7.9        5.0
# 17  Tunisia   May 2019        7.8        5.0
# 18  Tunisia   Jun 2019        7.8        5.0
# 19  Tunisia   Jul 2019        7.8        5.0
# 20  Tunisia   Aug 2019        7.8        5.0
# 21  Tunisia   Sep 2019        7.8        5.0
# 22  Tunisia   Oct 2019        7.8        5.0
# ...

# %%
df[['Unnamed: 1', 'Unnamed: 2']]
# Out:
#    Unnamed: 1 Unnamed: 2
# 1    Jan 2018        5.5
# 2    Feb 2018        5.6
# 3    Mar 2018        6.0
# 4    Apr 2018        6.5
# 5    May 2018        6.4
# 6    Jun 2018        6.7
# 7    Jul 2018        7.3
# 8    Aug 2018        7.3
# 9    Sep 2018        7.3
# 10   Oct 2018        7.3
# 11   Nov 2018        7.3
# 12   Dec 2018        7.2
# 13   Jan 2019        7.2
# 14   Feb 2019        7.3
# 15   Mar 2019        7.9
# 16   Apr 2019        7.9
# 17   May 2019        7.8
# 18   Jun 2019        7.8
# 19   Jul 2019        7.8
# 20   Aug 2019        7.8
# 21   Sep 2019        7.8
# 22   Oct 2019        7.8
# 23   Nov 2019        7.8

# %%
df = df[['Unnamed: 1', 'Unnamed: 2']]

# %%
df
# Out:
#    Unnamed: 1 Unnamed: 2
# 1    Jan 2018        5.5
# 2    Feb 2018        5.6
# 3    Mar 2018        6.0
# 4    Apr 2018        6.5
# 5    May 2018        6.4
# 6    Jun 2018        6.7
# 7    Jul 2018        7.3
# 8    Aug 2018        7.3
# 9    Sep 2018        7.3
# 10   Oct 2018        7.3
# 11   Nov 2018        7.3
# 12   Dec 2018        7.2
# 13   Jan 2019        7.2
# 14   Feb 2019        7.3
# 15   Mar 2019        7.9
# 16   Apr 2019        7.9
# 17   May 2019        7.8
# 18   Jun 2019        7.8
# 19   Jul 2019        7.8
# 20   Aug 2019        7.8
# 21   Sep 2019        7.8
# 22   Oct 2019        7.8
# 23   Nov 2019        7.8

# %%
df.plot.hist()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-35-aae26ac4cd3e> in <module>
# ----> 1 df.plot.hist()
#
# ~/.local/lib/python3.8/site-packages/pandas/plotting/_core.py in hist(self, by, bins, **kwargs)
#    1288             >>> ax = df.plot.hist(bins=12, alpha=0.5)
#    1289         """
# -> 1290         return self(kind="hist", by=by, bins=bins, **kwargs)
#    1291
#    1292     def kde(self, bw_method=None, ind=None, **kwargs):
#
# ~/.local/lib/python3.8/site-packages/pandas/plotting/_core.py in __call__(self, *args, **kwargs)
#     867
#     868     def __call__(self, *args, **kwargs):
# --> 869         plot_backend = _get_plot_backend(kwargs.pop("backend", None))
#     870
#     871         x, y, kind, kwargs = self._get_call_args(
#
# ~/.local/lib/python3.8/site-packages/pandas/plotting/_core.py in _get_plot_backend(backend)
# ...

# %%
new_data = df.rename(columns = {
    "Unnamed: 1" : "Date",
    "Unnamed: 2" : "MarketIntrest"
})

# %%
df.info
# Out:
# <bound method DataFrame.info of    Unnamed: 1 Unnamed: 2
# 1    Jan 2018        5.5
# 2    Feb 2018        5.6
# 3    Mar 2018        6.0
# 4    Apr 2018        6.5
# 5    May 2018        6.4
# 6    Jun 2018        6.7
# 7    Jul 2018        7.3
# 8    Aug 2018        7.3
# 9    Sep 2018        7.3
# 10   Oct 2018        7.3
# 11   Nov 2018        7.3
# 12   Dec 2018        7.2
# 13   Jan 2019        7.2
# 14   Feb 2019        7.3
# 15   Mar 2019        7.9
# 16   Apr 2019        7.9
# 17   May 2019        7.8
# 18   Jun 2019        7.8
# 19   Jul 2019        7.8
# 20   Aug 2019        7.8
# 21   Sep 2019        7.8
# 22   Oct 2019        7.8
# 23   Nov 2019        7.8>

# %%
adf = adf[['Tunisia, 11.12.2020','Unnamed: 1']]
adf = adf[1:]

# %%
adf1 	Jan 2018
# Out:
#    Tunisia, 11.12.2020 Unnamed: 1
# 1             Jan 2018       92.8
# 2             Feb 2018       88.3
# 3             Mar 2018       92.6
# 4             Apr 2018       89.5
# 5             May 2018       94.8
# 6             Jun 2018       94.2
# 7             Jul 2018       97.9
# 8             Aug 2018       89.0
# 9             Sep 2018       92.9
# 10            Oct 2018       94.1
# 11            Nov 2018       88.5
# 12            Dec 2018       91.3
# 13            Jan 2019       88.3
# 14            Feb 2019       86.3
# 15            Mar 2019       90.6
# 16            Apr 2019       86.8
# 17            May 2019       89.6
# 18            Jun 2019       89.4
# 19            Jul 2019       95.2
# 20            Aug 2019       85.1
# 21            Sep 2019       88.9
# 22            Oct 2019       91.0
# 23            Nov 2019       85.8
# 24            Dec 2019       92.3
# 25            Jan 2020       96.1
# 26            Feb 2020       93.9
# ...

# %%
bdf.rename(index = { 2: "2018-02-01",
                     3 : "2018-03-01",
                    4 : "2018-04-01",
                    5: "2018-05-01", 
                    6: "2018-06-01", 
                    7: "2018-07-01", 
                    8 : "2018-08-01", 
                    9: "2018-09-01", 
                    10 : "2018-10-01", 
                    11: "2018-11-01", 
                    12: "2018-12-01", 
                    13: "2018-01-01", 
                    14: "2019-02-01",
                    15: "2019-03-01",
                    16: "2019-04-01",
                    17: "2019-05-01", 
                    18: "2019-06-01", 
                    19: "2019-07-01", 
                    20: "2019-08-01", 
                    21: "2019-09-01", 
                    22: "2019-10-01", 
                    23: "2019-11-01", 
                    24: "2019-12-01", 
                    25: "2020-01-01", 
                    26: "2020-02-01",
                    27: "2020-03-01",
                    28: "2020-04-01",
                    29: "2020-05-01", 
                    30: "2020-06-01", 
                    31: "2020-07-01", 
                    32: "2020-08-01", 
                    33: "2020-09-01",}, 
                                 inplace = True)

# %%
adf.rename(index = {1: "2018-01-01"},inplace = 
          True)

# %%
adf
# Out:
#            Tunisia, 11.12.2020 Unnamed: 1
# 2018-01-01            Jan 2018       92.8
# 2018-02-01            Feb 2018       88.3
# 2018-03-01            Mar 2018       92.6
# 2018-04-01            Apr 2018       89.5
# 2018-05-01            May 2018       94.8
# 2018-06-01            Jun 2018       94.2
# 2018-07-01            Jul 2018       97.9
# 2018-08-01            Aug 2018       89.0
# 2018-09-01            Sep 2018       92.9
# 2018-10-01            Oct 2018       94.1
# 2018-11-01            Nov 2018       88.5
# 2018-12-01            Dec 2018       91.3
# 2018-01-01            Jan 2019       88.3
# 2019-02-01            Feb 2019       86.3
# 2019-03-01            Mar 2019       90.6
# 2019-04-01            Apr 2019       86.8
# 2019-05-01            May 2019       89.6
# 2019-06-01            Jun 2019       89.4
# 2019-07-01            Jul 2019       95.2
# 2019-08-01            Aug 2019       85.1
# 2019-09-01            Sep 2019       88.9
# ...

# %%
adf.columns[1]
# Out:
# 'Unnamed: 1'

# %%
adf[['Unnamed: 1']]
# Out:
#            Unnamed: 1
# 2018-01-01       92.8
# 2018-02-01       88.3
# 2018-03-01       92.6
# 2018-04-01       89.5
# 2018-05-01       94.8
# 2018-06-01       94.2
# 2018-07-01       97.9
# 2018-08-01       89.0
# 2018-09-01       92.9
# 2018-10-01       94.1
# 2018-11-01       88.5
# 2018-12-01       91.3
# 2018-01-01       88.3
# 2019-02-01       86.3
# 2019-03-01       90.6
# 2019-04-01       86.8
# 2019-05-01       89.6
# 2019-06-01       89.4
# 2019-07-01       95.2
# 2019-08-01       85.1
# 2019-09-01       88.9
# 2019-10-01       91.0
# 2019-11-01       85.8
# 2019-12-01       92.3
# 2020-01-01       96.1
# 2020-02-01       93.9
# 2020-03-01       78.3
# 2020-04-01       52.6
# 2020-05-01       71.7
# 2020-06-01       92.8
# 2020-07-01       93.3
# 2020-08-01       86.8
# 2020-09-01       89.1

# %%
adf = adf[['Unnamed: 1']]

# %%
adf
# Out:
#            Unnamed: 1
# 2018-01-01       92.8
# 2018-02-01       88.3
# 2018-03-01       92.6
# 2018-04-01       89.5
# 2018-05-01       94.8
# 2018-06-01       94.2
# 2018-07-01       97.9
# 2018-08-01       89.0
# 2018-09-01       92.9
# 2018-10-01       94.1
# 2018-11-01       88.5
# 2018-12-01       91.3
# 2018-01-01       88.3
# 2019-02-01       86.3
# 2019-03-01       90.6
# 2019-04-01       86.8
# 2019-05-01       89.6
# 2019-06-01       89.4
# 2019-07-01       95.2
# 2019-08-01       85.1
# 2019-09-01       88.9
# 2019-10-01       91.0
# 2019-11-01       85.8
# 2019-12-01       92.3
# 2020-01-01       96.1
# 2020-02-01       93.9
# 2020-03-01       78.3
# 2020-04-01       52.6
# 2020-05-01       71.7
# 2020-06-01       92.8
# 2020-07-01       93.3
# 2020-08-01       86.8
# 2020-09-01       89.1

# %%
df.to_csv('IPIclean.csv')

# %%
adf.to_csv('IPIcleaN.csv')

# %%
bdf=pd.read_csv('BalanceComm.csv')

# %%
bdf
# Out:
#          44176           Unnamed: 1
# 0      Période  Balance commerciale
# 1      Période              Tunisie
# 2   janv. 2017             -1,221.8
# 3   janv. 2018             -1,209.6
# 4   févr. 2018             -1,003.7
# 5    mars 2018             -1,439.7
# 6    avr. 2018             -1,430.5
# 7     mai 2018             -1,539.1
# 8    juin 2018             -1,540.4
# 9   juil. 2018             -1,781.6
# 10   août 2018              2,214.0
# 11  sept. 2018             -2,022.7
# 12   oct. 2018             -1,802.3
# 13   nov. 2018             -1,344.5
# 14   déc. 2018             -1,719.2
# 15  janv. 2019             -1,568.3
# 16  févr. 2019               -894.1
# 17   mars 2019             -1,510.9
# 18   avr. 2019             -2,363.6
# 19    mai 2019             -1,769.1
# 20   juin 2019             -1,674.5
# 21  juil. 2019             -1,383.3
# 22   août 2019             -1,700.3
# 23  sept. 2019             -1,984.0
# 24   oct. 2019             -1,658.4
# ...

# %%
bdf= bdf[2:]

# %%
bdf
# Out:
#          44176 Unnamed: 1
# 2   janv. 2017   -1,221.8
# 3   janv. 2018   -1,209.6
# 4   févr. 2018   -1,003.7
# 5    mars 2018   -1,439.7
# 6    avr. 2018   -1,430.5
# 7     mai 2018   -1,539.1
# 8    juin 2018   -1,540.4
# 9   juil. 2018   -1,781.6
# 10   août 2018    2,214.0
# 11  sept. 2018   -2,022.7
# 12   oct. 2018   -1,802.3
# 13   nov. 2018   -1,344.5
# 14   déc. 2018   -1,719.2
# 15  janv. 2019   -1,568.3
# 16  févr. 2019     -894.1
# 17   mars 2019   -1,510.9
# 18   avr. 2019   -2,363.6
# 19    mai 2019   -1,769.1
# 20   juin 2019   -1,674.5
# 21  juil. 2019   -1,383.3
# 22   août 2019   -1,700.3
# 23  sept. 2019   -1,984.0
# 24   oct. 2019   -1,658.4
# 25   nov. 2019   -1,292.8
# 26   déc. 2019   -1,609.4
# 27  janv. 2020     -970.5
# 28  févr. 2020   -1,348.5
# 29   mars 2020   -1,186.6
# 30   avr. 2020   -1,338.8
# 31    mai 2020   -1,255.4
# 32   juin 2020     -502.9
# 33  juil. 2020     -964.3
# 34   août 2020   -1,646.5
# 35  sept. 2020     -922.8
# ...

# %%
bdf.rename(index = { 2: "2018-01-01",
                     3 : "2018-02-01",
                    4 : "2018-03-01",
                    5: "2018-04-01", 
                    6: "2018-05-01", 
                    7: "2018-06-01", 
                    8 : "2018-07-01", 
                    9: "2018-08-01", 
                    10 : "2018-09-01", 
                    11: "2018-10-01", 
                    12: "2018-11-01", 
                    13: "2018-12-01", 
                    14: "2019-01-01",
                    15: "2019-02-01",
                    16: "2019-03-01",
                    17: "2019-04-01", 
                    18: "2019-05-01", 
                    19: "2019-06-01", 
                    20: "2019-07-01", 
                    21: "2019-08-01", 
                    22: "2019-09-01", 
                    23: "2019-10-01", 
                    24: "2019-11-01", 
                    25: "2020-12-01", 
                    26: "2020-01-01",
                    27: "2020-02-01",
                    28: "2020-03-01",
                    29: "2020-04-01", 
                    30: "2020-05-01", 
                    31: "2020-06-01", 
                    32: "2020-07-01", 
                    33: "2020-08-01",34: "2020-09-01",35: "2020-09-01",36: "2020-10-01",37: "2020-11-01",}, 
                                 inplace = True)

# %%
bdf = bdf[['Unnamed: 1']]
bdf
# Out:
#            Unnamed: 1
# 2018-02-01   -1,221.8
# 2018-03-01   -1,209.6
# 2018-04-01   -1,003.7
# 2018-05-01   -1,439.7
# 2018-06-01   -1,430.5
# 2018-07-01   -1,539.1
# 2018-08-01   -1,540.4
# 2018-09-01   -1,781.6
# 2018-10-01    2,214.0
# 2018-11-01   -2,022.7
# 2018-12-01   -1,802.3
# 2018-01-01   -1,344.5
# 2019-02-01   -1,719.2
# 2019-03-01   -1,568.3
# 2019-04-01     -894.1
# 2019-05-01   -1,510.9
# 2019-06-01   -2,363.6
# 2019-07-01   -1,769.1
# 2019-08-01   -1,674.5
# 2019-09-01   -1,383.3
# 2019-10-01   -1,700.3
# 2019-11-01   -1,984.0
# 2019-12-01   -1,658.4
# 2020-01-01   -1,292.8
# 2020-02-01   -1,609.4
# 2020-03-01     -970.5
# 2020-04-01   -1,348.5
# 2020-05-01   -1,186.6
# 2020-06-01   -1,338.8
# 2020-07-01   -1,255.4
# 2020-08-01     -502.9
# 2020-09-01     -964.3
# 2020-09-01   -1,646.5
# 2020-09-01     -922.8
# 2020-10-01     -643.5
# 2020-11-01     -886.6

# %%
bdf.to_csv('BalCom.csv')

# %%
cdf = pd.read_csv('CroissancePIBvarTri.csv')

# %%
cdf
# Out:
#                          Données CVS-CJO aux prix N-1  \
# 0                                                 NaN
# 1                                AGRICULTURE ET PECHE
# 2                          INDUSTRIES MANUFACTURIERES
# 3                        Industries agro-alimentaires
# 4            Industries textiles, habillement et cuir
# 5                                 Industries diverses
# 6                                Raffinage de pétrole
# 7                                Industries chimiques
# 8          Materiaux de construct. céramique et verre
# 9                Industries mécaniques et électriques
# 10                    INDUSTRIES  NON MANUFACTURIERES
# 11               Extraction de pétrole et gaz naturel
# 12                                              MINES
# 13                                 Electricité et gaz
# 14                                                Eau
# 15                            BÂTIMENT ET GENIE CIVIL
# ...

# %%
#concatinating tables : Balcom.csv/impExpF.csv/IPIcleaN.csv/MTT.csv/PIBf.csv/varPIBf.csv

# %%
import pandas as pd

# %%
df = pd.read_csv('BalCom.csv')
df1 = pd.read_csv('MTT.csv')
frames1 = [df ,df]
tst = pd.concat(frames1)
